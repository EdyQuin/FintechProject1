# %%
import pandas as pd
from pathlib import Path

# %%
# Miami
csv_miami_by_city = Path ('miami/compared_breakdown_by_city_miami.csv')
miami_breakdown_df = pd.read_csv(csv_miami_by_city)
interest_over_time_miami = Path('miami/interest_over_time_miami.csv')
miami_over_time_df = pd.read_csv(interest_over_time_miami)

#Tampa
csv_tampa_by_city = Path('tampa/by_city_tampa.csv')
tampa_breakdown_df = pd.read_csv(csv_tampa_by_city)
interest_over_time_tampa = Path('tampa/interest_over_time_tampa.csv')
tampa_over_time_df = pd.read_csv(interest_over_time_tampa)

#Orlando
csv_orlando_by_city = Path('orlando/compared_breakdown_by_city_orlando.csv')
orlando_breakdown_df = pd.read_csv(csv_orlando_by_city)
interest_over_time_orlando = Path ('orlando/interest_over_time_orlando.csv')
orlando_over_time_df = Path(interest_over_time_orlando)

# %%
miami_breakdown_df.head()
# Out:
#                City Pizza: (1/31/21 - 1/31/22) Sushi: (1/31/21 - 1/31/22)  \
# 0          Key West                        49%                         9%
# 1  Lighthouse Point                        52%                        17%
# 2       Miami Beach                        44%                        20%
# 3   Fort Lauderdale                        48%                        18%
# 4          Aventura                        45%                        31%
#
#   Pasta: (1/31/21 - 1/31/22) vegetarian: (1/31/21 - 1/31/22)  \
# 0                         7%                              3%
# 1                        12%                              1%
# 2                        12%                              2%
# 3                        15%                              2%
# 4                        11%                              2%
#
#   Seafood: (1/31/21 - 1/31/22)
# 0                          32%
# 1                          18%
# 2                          22%
# ...

# %%
tampa_breakdown_df.head()
# Out:
#              City Pizza: (1/31/21 - 1/31/22) Sushi: (1/31/21 - 1/31/22)  \
# 0      Siesta Key                        55%                        13%
# 1        Seminole                        57%                         8%
# 2        Sarasota                        54%                        15%
# 3  North Sarasota                        56%                        15%
# 4    Four Corners                        57%                        12%
#
#   Pasta: (1/31/21 - 1/31/22) vegetarian: (1/31/21 - 1/31/22)  \
# 0                         6%                             NaN
# 1                         6%                              2%
# 2                         9%                              2%
# 3                        15%                              3%
# 4                         9%                              2%
#
#   Seafood: (1/31/21 - 1/31/22)
# 0                          26%
# 1                          27%
# 2                          20%
# 3                          11%
# ...

# %%
tampa_breakdown_df.head()
# Out:
#              City Pizza: (1/31/21 - 1/31/22) Sushi: (1/31/21 - 1/31/22)  \
# 0      Siesta Key                        55%                        13%
# 1        Seminole                        57%                         8%
# 2        Sarasota                        54%                        15%
# 3  North Sarasota                        56%                        15%
# 4    Four Corners                        57%                        12%
#
#   Pasta: (1/31/21 - 1/31/22) vegetarian: (1/31/21 - 1/31/22)  \
# 0                         6%                             NaN
# 1                         6%                              2%
# 2                         9%                              2%
# 3                        15%                              3%
# 4                         9%                              2%
#
#   Seafood: (1/31/21 - 1/31/22)
# 0                          26%
# 1                          27%
# 2                          20%
# 3                          11%
# ...
